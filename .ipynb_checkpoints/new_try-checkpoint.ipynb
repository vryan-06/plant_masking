# %%
import cv2
from plantcv import plantcv as pcv

# %matplotlib inline
from matplotlib import pyplot as plt

# %%
img = cv2.imread("collected_data/p1.jpeg")

# %%
s = pcv.rgb2gray_hsv(rgb_img=img, channel='s')
binary_mask = pcv.threshold.binary(gray_img=s, threshold=85, max_value=255, object_type='light')

# %%
plt.imshow(img)
plt.show()

# %%
# cv2.imshow(" ", binary_mask)

cv2.imshow(" ", img)

# %%
color_analysis = pcv.color.analyze_color(img)

# Print the color analysis results
print(color_analysis)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 color_analysis = pcv.color.analyze_color(img)
#       3 # Print the color analysis results
#       4 print(color_analysis)
#
# AttributeError: module 'plantcv.plantcv' has no attribute 'color'
